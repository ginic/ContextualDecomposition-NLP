# %%
import json
import pickle
import string

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE

import torch
import torch.nn

from morpho_tagging.networks import *
from morpho_tagging.train import parser

# %%
# Paths to model outputs
model_root = "/home/virginia/workspace/CS682_NNs_Nerual_Char_Models_Russian/language_models"
model_name = "bilstm_batch20_dropout0.50_charembedsize50_learningrate0.001_hiddensize200"
best_model = f"{model_root}/{model_name}/tagger_ru_data_19_Nov_2021_15_21_41_best"
model_settings = f"{model_root}/{model_name}/tagger_ru_settings_19_Nov_2021_15_21_41"
char_vocab_path = f"{model_root}/{model_name}/tagger_ru_charvocab_19_Nov_2021_15_21_41"
word_vocab_path = f"{model_root}/{model_name}/tagger_ru_wordvocab_19_Nov_2021_15_21_41"

# %%
device="cpu"
load_params = parser.parse_args(["--training_type", "lm", "--data_path_ud", "dummy", "--save_dir", "dummy", "--pretrained_model", best_model, "--pretrained_settings", model_settings])

with open(load_params.pretrained_settings) as settings_in:
    print("Loading model settings")
    settings_json = json.load(settings_in)
    for k in settings_json:
        if k != 'pretrained_model':
            setattr(load_params, k, settings_json[k])
        if k == "tagset_size":
            tagset_sizes = {}
            for a, v in settings_json[k].items():
                tagset_sizes[int(a)]=v
            setattr(load_params, k, tagset_sizes)
        
print(load_params)

model = Tagger(load_params, device)
model.load_state_dict(torch.load(load_params.pretrained_model, map_location=torch.device('cpu')))

with open(char_vocab_path, 'rb') as vocab_in:
    char_vocab = pickle.load(vocab_in)

with open(word_vocab_path, 'rb') as words_in:
    word_vocab = pickle.load(words_in)
# Out:
# Loading model settings
# Namespace(batch_size=20, char_conv_act='relu', char_embedding_size=50, char_filter_sizes=[1, 2, 3, 4, 5, 6], char_gram=1, char_number_of_filters=[25, 50, 75, 100, 125, 150], char_rec_num_units=200, char_type='bilstm', char_vocab_size=185, data_path_ud='../CS682_NNs_Nerual_Char_Models_Russian/data', dropout_frac=0.5, language='ru', lm_hidden_size=100, lm_num_layers=1, lr=0.001, num_epochs=10, pad_index=0, pretrained_model='/home/virginia/workspace/CS682_NNs_Nerual_Char_Models_Russian/language_models/bilstm_batch20_dropout0.50_charembedsize50_learningrate0.001_hiddensize200/tagger_ru_data_19_Nov_2021_15_21_41_best', pretrained_settings=None, save_dir='../CS682_NNs_Nerual_Char_Models_Russian/language_models/bilstm_batch20_dropout0.50_charembedsize50_learningrate0.001_hiddensize200', save_file='tagger_ru_', tagset_size={0: 20}, training_type='lm', unique_words=0, word_vocab_size=140768)

# %%
# Get CharEmbeddings from model 
char_embedding_weights = model.char_embeddings.weight.detach().numpy()

# %%
char_pca = PCA(2)
char_pca_proj = char_pca.fit_transform(char_embedding_weights)
char_pca_proj[:5]
# Out:
# array([[-0.02206808, -0.36061057],
#        [-0.02712364, -0.3608984 ],
#        [-0.02250194, -0.3649827 ],
#        [ 0.9504763 , -0.30451033],
#        [ 0.43161595, -0.3247251 ]], dtype=float32)

# %%
tsne = TSNE(2)
char_tsne_proj = tsne.fit_transform(char_embedding_weights)
char_tsne_proj[:5]
# Out:
# /home/virginia/miniconda3/envs/682_final_proj/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /home/virginia/miniconda3/envs/682_final_proj/lib/python3.7/site-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
# array([[-0.48687455,  2.0837975 ],
#        [-0.4864395 ,  2.079922  ],
#        [-0.49607545,  2.082732  ],
#        [-4.0392017 ,  0.75526965],
#        [-4.033892  ,  1.0098848 ]], dtype=float32)

# %%
def get_char_class(char):
    """Returns 'digit', 'upper', 'lower', 'punct' or 'special' 
    """
    if char.isdigit():
        return 'digit'
    if char in ["<unk>", "<pad>", "<special_token>", "<eow>", "<sow>", "<eos>", "<sos>"]:
        return 'special'
    if char.isupper():
        return 'upper'
    if char.islower():
        return 'lower'
    if char in string.punctuation:
        return 'punctuation'
    else:
        return 'symbol'

# %%
# build dataframe
entries = []
for k, char_idx in char_vocab.char_to_index.items():
    char_type = get_char_class(k)
    entries.append((k, char_idx, char_type, char_pca_proj[char_idx][0], char_pca_proj[char_idx][1], char_tsne_proj[char_idx][0], char_tsne_proj[char_idx][1]))

char_plot_df = pd.DataFrame.from_records(entries, columns=["char", "embedding_index", "char_class", "pca_x", "pca_y", "tsne_x", "tsne_y"])

# %%
plt.figure(figsize=(10,10))
ax = sns.scatterplot(data = char_plot_df, x="pca_x", y="pca_y", hue="char_class")
for k, char_idx in char_vocab.char_to_index.items():
    ax.text(char_pca_proj[char_idx][0], char_pca_proj[char_idx][1], k)

# %%
plt.figure(figsize=(8, 8))
ax = sns.scatterplot(data = char_plot_df, x="tsne_x", y="tsne_y", hue="char_class")
#for k, char_idx in char_vocab.char_to_index.items():
#    ax.text(char_tsne_proj[char_idx][0], char_tsne_proj[char_idx][1], k)
ax.set(xlabel=None)
ax.set(ylabel=None)
ax.set(title="TSNE projection of character embeddings")
ax.get_legend().set_title("Character class")
plt.legend(loc='lower right')

# %%
# Get embeddings for all words in the training data
def get_word_embedding_input_batch(word_vocab, char_vocab, model, word_embedding_size):
    """Returns the embeddings as (word_vocab_size, embedding_size) np array, where the 
    embedding for a word is at the same index assigned to the word in the word vocab. 
    The returned array can be fed to distance metrics up nearest neighbors in the learned word vocabulary.
    """
    lengths = [1, 1, 1] # Lengths for padding, start and end of sentence
    print("Word to index size:", len(word_vocab.word_to_index))
    index_to_word = {v:k for k, v in word_vocab.word_to_index.items()}
    print("Index to word size:", len(index_to_word))
    print("Those two numbers should match")
    max_length = max([len(v) for v in word_vocab.word_to_char_embedding.values()])
    words_in = np.zeros((word_vocab.vocab_size(), max_length))
    print(words_in.shape)
    # Start and end of sentence
    words_in[1][0:1] = np.array(char_vocab.char_to_index["<sos>"])
    words_in[2][0:1] = np.array(char_vocab.char_to_index["<eos>"])
    for w, idx in word_vocab.word_to_index.items():
        embedding = word_vocab.word_to_char_embedding[w]
        emb_len = len(embedding)
        lengths.append(emb_len)
        words_in[idx][0:emb_len] = np.array(embedding)
    print(len(words_in))

    model.eval()
    word_embedding_batches = []
    # Break up words in vocab into smaller batches so there aren't any memory issues
    word_char_batches = np.array_split(words_in, word_embedding_size)
    start = 0
    for b in word_char_batches:
        end = start+ b.shape[0]
        if start % 50==0: print("Batch from", start, "to", end)
        batch_emb = model.get_word_embeddings(b, np.array(lengths[start:end])).detach().numpy()
        if batch_emb.shape[0] != (b.shape[0]):
            print("Batch doesn't match, start:", start, "end:", end)
        word_embedding_batches.append(batch_emb)
        start = end

    word_embeddings = np.vstack(word_embedding_batches)
    print("Embedding shape:", word_embeddings.shape)
    return word_embeddings

# %%
word_embeddings = get_word_embedding_input_batch(word_vocab, char_vocab, model, 400)
# Out:
# Word to index size: 140765
# Index to word size: 140765
# Those two numbers should match
# (140768, 101)
# 140768
# Batch from 0 to 352
# Batch from 8800 to 9152
# Batch from 17600 to 17952
# Batch from 26400 to 26752
# Batch from 35200 to 35552
# Batch from 44000 to 44352
# Batch from 52800 to 53152
# Batch from 61600 to 61952
# Batch from 70400 to 70752
# Batch from 79200 to 79552
# Batch from 88000 to 88352
# Batch from 96800 to 97152
# Batch from 105600 to 105952
# Batch from 114400 to 114752
# Batch from 123200 to 123552
# Batch from 134450 to 134801
# Embedding shape: (140768, 400)

# %%
from sklearn.metrics.pairwise import cosine_similarity

def get_most_similar_words(word, word_embeddings, word_vocab, n=10):
    """Given a word, looks up its index in the word_vocab, then returns a list
    of the n most similar words using cosine similarity of the word embeddings
    produced by the model.
    """
    word_idx = word_vocab.word_to_index[word]
    print("Word:", word, "Index:", word_idx)
    this_embedding = word_embeddings[word_idx].reshape(1, -1)
    similarities = cosine_similarity(this_embedding, word_embeddings)
    # Note that this sorts in increasing order, so the most similar are at the end
    most_similar_idx = np.argsort(similarities, axis=1).reshape(-1)
    idx_to_word = {v:k for k,v in word_vocab.word_to_index.items()}
    word_list = []
    for i in range(n):
        word_list.append(idx_to_word[most_similar_idx[-(i+2)]])

    print(word_list)
    return word_list

# %%
word_list = ['большой', 'большая', 'мужчина', "женщина", 'женщины', "Москва", "говорить", "говоришь", "меня", "мне", "тебя", "тебе", "весна", "этот", "это", 'этой', 'эта', 'быть', 'было', 'в', 'красный', 'красная', 'красном', '?', '.', "любовь", "любви", "любить", "любила", "сказать", "рассказывать", "разговор", "привет", "спасибо", "нет", "хорошо", "хороший", "Саша", "ночь", "день", "днём", "и", "а", "но", "ну", "я", "он", "его", "она", "ее", "её", 'Россия', "России", "здравствуйте", "здравствуй", "книга", "книги", "собака", "собак", "собаки", "кошка", "кошки", "кошек", "когда", "где", "который", "которой"]

for w in word_list: 
    get_most_similar_words(w, word_embeddings, word_vocab)
# Out:
# Word: большой Index: 577
# ['небольшой', 'пребольшой', 'Небольшой', 'больной', 'белой', 'светлой', 'сверхбольшой', 'беговой', 'Большой', 'командной']
# Word: большая Index: 1347
# ['бОльшая', 'небольшая', 'наибольшая', 'пребольшая', 'нехорошая', 'Небольшая', 'Нехорошая', 'хорошая', 'Хорошая', 'уменьшая']
# Word: мужчина Index: 2209
# ['мужика', 'мамина', 'мезона', 'муженька', 'колонна', 'филина', 'малина', 'камина', 'дружина', 'маменька']
# Word: женщина Index: 603
# ['ангина', 'Горемыкина', 'Курникова', 'живехонька', 'апельсина', 'Аврамова', 'машина', 'животновода', 'железяки', 'желанна']
# Word: женщины Index: 3939
# ['желтизны', 'желательны', 'железы', 'желтозёмы', 'термины', 'балясины', 'женаты', 'бирючины', 'грузины', 'жилеты']
# Word: Москва Index: 4677
# ['Кудимова', 'Мосса', 'Минфина', 'Юшенкова', 'Шмакова', 'Логвинова', 'Грекова', 'Рафикова', 'Ломоносова', 'Михайловна']
# Word: говорить Index: 639
# ['говорите', 'говорило', 'говорят', 'говорили', 'говорила', 'говорится', 'говоришь', 'говните', 'Говорите', 'говорим']
# Word: говоришь Index: 9228
# ['говорило', 'говорили', 'говорим', 'говорится', 'говорильни', 'говорильня', 'говорите', 'говорун', 'говорилось', 'говорят']
# Word: меня Index: 607
# ['Меня', 'тебя', 'ясеня', 'Ясеня', 'неся', 'Саня', 'сегодня', 'Вася', 'майя', 'ячменя']
# Word: мне Index: 266
# ['мня', 'Мне', 'можем', 'мэоне', 'могла', 'мое', 'многое', 'могли', 'най', 'Многое']
# Word: тебя Index: 1849
# ['Тебя', 'меня', 'любя', 'такая', 'Такая', 'Самая', 'тебе', 'последняя', 'самая', 'яркая']
# Word: тебе Index: 4740
# ['Тебе', 'тебя', 'теле', 'Тебя', 'Тане', 'тоже', 'толще', 'Тэджоне', 'Туве', 'Бабе']
# Word: весна Index: 43697
# ['виновна', 'оригинальна', 'валуна', 'великолепна', 'Весна', 'пелена', 'неверна', 'сложна', 'пуха', 'войска']
# Word: этот Index: 445
# ['Этот', 'первый', 'сытый', 'вредный', 'второй', 'етот', 'обоюдный', 'плодородный', 'крытый', 'Второй']
# Word: это Index: 41
# ['Это', 'то-то', 'ото', 'эт-то', 'То-то', 'кому-то', 'нео', 'долгое', 'выгодные', 'Сыто']
# Word: этой Index: 764
# ['Этой', 'равной', 'нарядной', 'народной', 'нынешней', 'разрядной', 'портовой', 'начальной', 'нашей', 'нарядней']
# Word: эта Index: 1185
# ['Эта', 'Средняя', 'своя', 'нижняя', 'средняя', 'последняя', 'Осенённая', 'Внешняя', 'Последняя', 'Высшая']
# Word: быть Index: 152
# ['ныть', 'Быть', 'выть', 'Читать', 'Натальи', 'сбыть', 'считаюсь', 'были', 'Наталья', 'каюсь']
# Word: было Index: 135
# ['ныло', 'Было', 'быдло', 'мыло', 'выло', 'наболело', 'рыло', 'был', 'Пабло', 'нужнее']
# Word: в Index: 11
# ['В', 'при', 'всём', 'веб', 'ы', 'об', '<', 'Об', 'п', 'ври']
# Word: красный Index: 71378
# ['курортный', 'крупный', 'классный', 'красочный', 'крестный', 'крапивный', 'корыстный', 'Крестный', 'картонный', 'коронарный']
# Word: красная Index: 21584
# ['крупная', 'кирпичная', 'классная', 'кризисная', 'каркасная', 'Крупная', 'Красная', 'кухонная', 'остаточная', 'расписная']
# Word: красном Index: 47628
# ['серьёзном', 'капитальном', 'воскресном', 'субъективном', 'сингулярном', 'крапивном', 'сахарном', 'кузнечном', 'Красном', 'правильном']
# Word: ? Index: 19
# ['!', '…?', ')?', '»?', '»!', ']?', '"?', ')!', '"!', '%?']
# Word: . Index: 4
# ['*}.', 'qTc2).', '--.', ')×(b2,b1)=(d4,d3,d2,d1).', '$.', '**.', '--).', '….', 'int>x.', '+.']
# Word: любовь Index: 780
# ['морковь', 'нелюбовь', 'россыпь', 'гребень', 'свекровь', 'кухонь', 'клубень', 'пораскинь', 'сирень', 'пустынь']
# Word: любви Index: 10190
# ['колени', 'проливе', 'позови', 'назови', 'коллегии', 'извини', 'голуби', 'крапиве', 'усики', 'пневматологии']
# Word: любить Index: 8755
# ['уладить', 'ударить', 'ушибить', 'убить', 'ладить', 'делить', 'ущемить', 'лишать', 'лупить', 'набить']
# Word: любила Index: 13594
# ['угробила', 'полюбила', 'теребила', 'усугубила', 'слепила', 'либерала', 'делила', 'победила', 'трубила', 'научила']
# Word: сказать Index: 197
# ['скатать', 'сказали', 'скажете', 'скажите', 'скажет', 'Сказать', 'Сказали', 'Скажите', 'считаете', 'Скажет']
# Word: рассказывать Index: 1777
# ['расспрашивать', 'расписывать', 'рассчитать', 'рассчитывать', 'разыскивать', 'разбавить', 'расспросить', 'распознать', 'разговаривать', 'расквасить']
# Word: разговор Index: 2222
# ['заговор', 'приговор', 'договор', 'раствор', 'выговор', 'эланор', 'Уговор', 'сговор', 'прокурор', 'наперекор']
# Word: привет Index: 18044
# ['приспичит', 'выживет', 'спрячет', 'привезёт', 'притихнет', 'привыкнет', 'принесёт', 'проживёт', 'вырвет', 'просвет']
# Word: спасибо Index: 2282
# ['Спасибо', 'чудо', 'голубо', 'покончено', 'Подмечено', 'скучно', 'примитивно', 'пышно', 'подмечено', 'спорно']
# Word: нет Index: 279
# ['Нет', 'понят', 'нить', 'понято', 'Вите', 'понять', 'Н-нет', 'поймут', 'поймёте', 'помене']
# Word: хорошо Index: 137
# ['хмельно', 'халтурно', 'нарочно', 'бравурно', 'хищно', 'непросто', 'шумно', 'худо-бедно', 'судорожно', 'сукно']
# Word: хороший Index: 2102
# ['нехороший', 'лучший', 'милейший', 'расхороший', 'Хороший', 'хитрейший', 'промокший', 'Простейший', 'Ярчайший', 'дочерний']
# Word: Саша Index: 11433
# ['Саха', 'Нюша', 'каша', 'Паша', 'Каха', 'веса', 'сауна', 'Шануа', 'скучна', 'чаша']
# Word: ночь Index: 18735
# ['ночи', 'Ночь', 'умно', 'небо', 'умнее', 'Ночи', 'дождевик', 'ноч', 'уйдёшь', 'умах']
# Word: день Index: 3853
# ['дичь', 'День', 'дочь', 'дня', 'Дочь', 'дунь', 'дичи', 'дней', 'Дим', 'Диме']
# Word: днём Index: 11991
# ['Днём', 'дням', 'днем', 'дном', 'дней', 'Днем', 'Дней', 'дня', 'Джим', 'Дойче']
# Word: и Index: 162
# ['”', 'Щи', '→', 'и-и', '–', 'или', 'их', 'ви', 'сб', 'б']
# Word: а Index: 131
# ['И', 'А', 'ю', 'б', 'у', 'Но', 'Ща', 'ка', 'са', 'Только']
# Word: но Index: 234
# ['Но', 'чо', 'Оо', 'ибо', 'Вы', 'вы', 'нё', 'Ведь', 'ведь', 'Коти']
# Word: ну Index: 307
# ['Ну', 'ку', 'ху', 'чу', 'Му', 'Ау', 'Су', 'АУ', 'Так', 'Туда']
# Word: я Index: 89
# ['Я', 'й', 'ям', 'Ян', 'тоже', 'е', 'З', 'мня', 'ясли', 'он']
# Word: он Index: 348
# ['Он', 'Ок', 'они', 'Оп', 'Они', 'ок', 'Сон', 'Овёс', 'окон', 'Спок']
# Word: его Index: 1156
# ['иго', 'их', 'эго', 'Его', 'её', 'ими', 'совиные', 'ищи', 'сводные', 'Ого']
# Word: она Index: 153
# ['Она', 'Ока', 'Оса', 'ока', 'ёна', 'Опа', 'ОНИ', 'Сона', 'Снова', 'Сова']
# Word: ее Index: 111188
# ['те', 'же', 'той', 'Ле', 'иже', 'та', 'её', 'менее', 'тя', 'Те']
# Word: её Index: 1077
# ['Её', 'его', 'ее', 'сводные', 'неё', 'мои', 'таё', 'самые', 'сквозные', 'нё']
# Word: Россия Index: 45
# ['Рисса', 'Ропня', 'Революция', 'Линча', 'Россию', 'Ривз', 'Юхсия', 'Бион', 'Агрессия', 'Шина']
# Word: России Index: 188
# ['Росси', 'Римини', 'Россини', 'Ропни', 'Арктики', 'Шишки', 'Линии', 'Рисунки', 'Ростки', 'Богемии']
# Word: здравствуйте Index: 9249
# ['запишете', 'раскрывайте', 'запрещайте', 'сбрасывайте', 'запишите', 'записывайте', 'существуете', 'откладывайте', 'путешествуете', 'разглагольствуете']
# Word: здравствуй Index: 73302
# ['говорящий', 'властвуй', 'залатать', 'поучаствуй', 'говорящее', 'пожеланий', 'Здравствуйте', 'участвуй', 'Здравствуй', 'доверяете']
# Word: книга Index: 2334
# ['Книга', 'блога', 'книгу', 'пирога', 'ранга', 'книги', 'пудинга', 'сдвига', 'мига', 'клиринга']
# Word: книги Index: 2384
# ['книгу', 'Книги', 'книге', 'пироги', 'книга', 'Кафки', 'спелеологи', 'пастухи', 'Книгу', 'политики']
# Word: собака Index: 9161
# ['собачка', 'скачка', 'кизяка', 'Собака', 'классика', 'критика', 'сучка', 'кусочка', 'кубка', 'сумрака']
# Word: собак Index: 22934
# ['пиджак', 'паук', 'скачков', 'судак', 'небак', 'скачок', 'колпак', 'кабак', 'кабачок', 'справок']
# Word: собаки Index: 29821
# ['скачки', 'сосунки', 'собачки', 'кабаки', 'смазки', 'соседки', 'пауки', 'снежки', 'Собаки', 'казни']
# Word: кошка Index: 91943
# ['Кошка', 'порошка', 'мешка', 'насмешка', 'колюшка', 'вещмешка', 'коротышка', 'матрьошка', 'усмешка', 'кишка']
# Word: кошки Index: 12744
# ['пышки', 'кишки', 'копейки', 'пёрышки', 'шишки', 'мешки', 'койки', 'корешки', 'пешки', 'окошки']
# Word: кошек Index: 28272
# ['катушек', 'краешек', 'клюшек', 'доминошек', 'старушек', 'корзиночек', 'костяшек', 'пышек', 'игрушек', 'вертушек']
# Word: когда Index: 543
# ['Когда', 'которому', 'что', 'котором', 'Сейчас', 'Все-таки', 'чего', 'Всё-таки', 'которым', 'которого']
# Word: где Index: 2353
# ['Где', 'Мде', 'Которой', 'чем', 'что', 'Хоть', 'котята', 'Кем', 'Сейчас', 'чего']
# Word: который Index: 1050
# ['которые', 'которых', 'которого', 'которыми', 'которой', 'которым', 'которое', 'которую', 'котором', 'которому']
# Word: которой Index: 754
# ['котором', 'которую', 'которого', 'которые', 'которому', 'которыми', 'которых', 'которым', 'который', 'которое']
